# %%
#!pip install pymongo

# %%
import pandas as pd
from pymongo import MongoClient
from pymongo.errors import OperationFailure

# %% [markdown]
# ## Lesson 1

# %%
url = 'mongodb://localhost:27017'
client = MongoClient(url)

try:
    db = client['mydb']
    collection = db['orders']
    
    cursor = collection.find()
    
    for s in cursor:
        print(f"{s['name']} : {s['cost']}" )
    cursor.close()

except OperationFailure as e:
    print(f"Error:\n {e}")
finally:
    client.close()
    
client.close()
# Out:
# Thomson Yeung : 888
# Alice Wong : 999
# Ada Pang : 5

# %% [markdown]
# ## Lesson 2

# %%
def show_collect(mycol, myquery):
    list_cur = list(mycol.find(myquery))
    df = pd.DataFrame(list_cur)

    cols = list(df.columns)
    df = df[cols[1:]]
    return(df)

def show_collect_sort(mycol, mysort):
    list_cur = list(mycol.find().sort(mysort['field'], mysort['asc']))
    #list_cur = list(mycol.find().sort(mysort))
    df = pd.DataFrame(list_cur)

    cols = list(df.columns)
    df = df[cols[1:]]
    return(df)

# %%
tutorial1 = {
     "title": "Reading and Writing CSV Files in Python",
     "author": "Jon",
     "contributors": [
         "Aldren",
         "Geir Arne",
         "Joanna",
         "Jason"
     ],
     "url": "https://realpython.com/python-csv/"
}

tutorial2 = {
    "title": "How to Iterate Through a Dictionary in Python",
    "author": "Leodanis",
    "contributors": [
        "Aldren",
        "Jim",
        "Joanna"
    ],
    "url": "https://realpython.com/iterate-through-dictionary-python/"
}

tutorial3 = {
      "title": "Python 3's f-Strings: An Improved String Formatting Syntax",
      "author": "Joanna",
      "contributors": [
          "Adriana",
          "David",
          "Dan",
          "Jim",
          "Pavel"
      ],
      "url": "https://realpython.com/python-f-strings/"
}

tutorial4 = {
      "title": "Basket Ball Training",
      "author": "Coach Fui",
      "contributors": [
          "Thomson Yeung",
          "Adam Ma"
      ],
      "url": "https://basketball.com/coachfui/"
}

# %%
url = 'mongodb://localhost:27017'
client = MongoClient(url)

db = client['mydb']
tutorials = db['tutorials']

tutorials.delete_many({})
tutorials.insert_many([tutorial1, tutorial2, tutorial3])


#client.close()

# %%
tutorials.insert_one(tutorial4)

# %%
df_tutorials = show_collect(tutorials, {})
df_tutorials
# select * from tutorials
# Out:
#                                                title     author  \
# 0            Reading and Writing CSV Files in Python        Jon
# 1      How to Iterate Through a Dictionary in Python   Leodanis
# 2  Python 3's f-Strings: An Improved String Forma...     Joanna
# 3                               Basket Ball Training  Coach Fui
#
#                          contributors  \
# 0  [Aldren, Geir Arne, Joanna, Jason]
# 1               [Aldren, Jim, Joanna]
# 2   [Adriana, David, Dan, Jim, Pavel]
# 3            [Thomson Yeung, Adam Ma]
#
#                                                  url
# 0                 https://realpython.com/python-csv/
# 1  https://realpython.com/iterate-through-diction...
# 2           https://realpython.com/python-f-strings/
# 3                   https://basketball.com/coachfui/

# %%
myquery = {'author': 'Joanna'}
df_tutorials = show_collect(tutorials, myquery)
df_tutorials
# select * from tutorials where author = 'Joanna'
# Out:
#                                                title  author  \
# 0  Python 3's f-Strings: An Improved String Forma...  Joanna
#
#                         contributors                                       url
# 0  [Adriana, David, Dan, Jim, Pavel]  https://realpython.com/python-f-strings/

# %%
myquery = {'author': {'$ne': 'Joanna'}}
df_tutorials = show_collect(tutorials, myquery)
df_tutorials
# select * from tutorials where author <> 'Joanna'
# Out:
#                                            title     author  \
# 0        Reading and Writing CSV Files in Python        Jon
# 1  How to Iterate Through a Dictionary in Python   Leodanis
# 2                           Basket Ball Training  Coach Fui
#
#                          contributors  \
# 0  [Aldren, Geir Arne, Joanna, Jason]
# 1               [Aldren, Jim, Joanna]
# 2            [Thomson Yeung, Adam Ma]
#
#                                                  url
# 0                 https://realpython.com/python-csv/
# 1  https://realpython.com/iterate-through-diction...
# 2                   https://basketball.com/coachfui/

# %%
myquery = {'title': {'$regex': '^Python'}}
df_tutorials = show_collect(tutorials, myquery)
df_tutorials
# select * from tutorials where title like 'Python%'
# Out:
#                                                title  author  \
# 0  Python 3's f-Strings: An Improved String Forma...  Joanna
#
#                         contributors                                       url
# 0  [Adriana, David, Dan, Jim, Pavel]  https://realpython.com/python-f-strings/

# %%
mysort = {'field': 'title', 'asc': 1}
df_tutorials = show_collect_sort(tutorials, mysort)
df_tutorials
# select * from tutorials order by title asc
# Out:
#                                                title     author  \
# 0                               Basket Ball Training  Coach Fui
# 1      How to Iterate Through a Dictionary in Python   Leodanis
# 2  Python 3's f-Strings: An Improved String Forma...     Joanna
# 3            Reading and Writing CSV Files in Python        Jon
#
#                          contributors  \
# 0            [Thomson Yeung, Adam Ma]
# 1               [Aldren, Jim, Joanna]
# 2   [Adriana, David, Dan, Jim, Pavel]
# 3  [Aldren, Geir Arne, Joanna, Jason]
#
#                                                  url
# 0                   https://basketball.com/coachfui/
# 1  https://realpython.com/iterate-through-diction...
# 2           https://realpython.com/python-f-strings/
# 3                 https://realpython.com/python-csv/

# %%
mysort = {'field': 'title', 'asc': -1}
#mysort = {'title':  -1}

df_tutorials = show_collect_sort(tutorials, mysort)
df_tutorials
# select * from tutorials order by title desc
# Out:
#                                                title     author  \
# 0            Reading and Writing CSV Files in Python        Jon
# 1  Python 3's f-Strings: An Improved String Forma...     Joanna
# 2      How to Iterate Through a Dictionary in Python   Leodanis
# 3                               Basket Ball Training  Coach Fui
#
#                          contributors  \
# 0  [Aldren, Geir Arne, Joanna, Jason]
# 1   [Adriana, David, Dan, Jim, Pavel]
# 2               [Aldren, Jim, Joanna]
# 3            [Thomson Yeung, Adam Ma]
#
#                                                  url
# 0                 https://realpython.com/python-csv/
# 1           https://realpython.com/python-f-strings/
# 2  https://realpython.com/iterate-through-diction...
# 3                   https://basketball.com/coachfui/

# %%
myquery = {'author': 'Joanna'}
tutorials.delete_many(myquery)
df_tutorials = show_collect(tutorials, {})
df_tutorials
# delete from tutorials where author = 'Joanna'
# Out:
#                                            title     author  \
# 0        Reading and Writing CSV Files in Python        Jon
# 1  How to Iterate Through a Dictionary in Python   Leodanis
# 2                           Basket Ball Training  Coach Fui
#
#                          contributors  \
# 0  [Aldren, Geir Arne, Joanna, Jason]
# 1               [Aldren, Jim, Joanna]
# 2            [Thomson Yeung, Adam Ma]
#
#                                                  url
# 0                 https://realpython.com/python-csv/
# 1  https://realpython.com/iterate-through-diction...
# 2                   https://basketball.com/coachfui/

# %%
tutorials.delete_many({})
tutorials.insert_many([tutorial1, tutorial2, tutorial3, tutorial4])
df_tutorials = show_collect(tutorials, {})
df_tutorials
# rollback
# Out:
#                                                title     author  \
# 0            Reading and Writing CSV Files in Python        Jon
# 1      How to Iterate Through a Dictionary in Python   Leodanis
# 2  Python 3's f-Strings: An Improved String Forma...     Joanna
# 3                               Basket Ball Training  Coach Fui
#
#                          contributors  \
# 0  [Aldren, Geir Arne, Joanna, Jason]
# 1               [Aldren, Jim, Joanna]
# 2   [Adriana, David, Dan, Jim, Pavel]
# 3            [Thomson Yeung, Adam Ma]
#
#                                                  url
# 0                 https://realpython.com/python-csv/
# 1  https://realpython.com/iterate-through-diction...
# 2           https://realpython.com/python-f-strings/
# 3                   https://basketball.com/coachfui/

# %%
myquery = { "author": "Jon" }
newvalues = { "$set": { "author": "Thomson Yeung" } }

tutorials.update_one(myquery, newvalues)
df_tutorials = show_collect(tutorials, {})
df_tutorials
# update tutorials set author = 'Thomson Yeung' where author = 'Jon'
# Out:
#                                                title         author  \
# 0            Reading and Writing CSV Files in Python  Thomson Yeung
# 1      How to Iterate Through a Dictionary in Python       Leodanis
# 2  Python 3's f-Strings: An Improved String Forma...         Joanna
# 3                               Basket Ball Training      Coach Fui
#
#                          contributors  \
# 0  [Aldren, Geir Arne, Joanna, Jason]
# 1               [Aldren, Jim, Joanna]
# 2   [Adriana, David, Dan, Jim, Pavel]
# 3            [Thomson Yeung, Adam Ma]
#
#                                                  url
# 0                 https://realpython.com/python-csv/
# 1  https://realpython.com/iterate-through-diction...
# 2           https://realpython.com/python-f-strings/
# 3                   https://basketball.com/coachfui/

# %%
myquery = { "author": {"$ne": "Thomson Yeung" }}
newvalues = { "$set": { "author": "Alice Wong" } }

tutorials.update_many(myquery, newvalues)
df_tutorials = show_collect(tutorials, {})
df_tutorials
# update tutorials set author = 'Alice Wong' where author <> 'Thomson Yeung'
# Out:
#                                                title         author  \
# 0            Reading and Writing CSV Files in Python  Thomson Yeung
# 1      How to Iterate Through a Dictionary in Python     Alice Wong
# 2  Python 3's f-Strings: An Improved String Forma...     Alice Wong
# 3                               Basket Ball Training     Alice Wong
#
#                          contributors  \
# 0  [Aldren, Geir Arne, Joanna, Jason]
# 1               [Aldren, Jim, Joanna]
# 2   [Adriana, David, Dan, Jim, Pavel]
# 3            [Thomson Yeung, Adam Ma]
#
#                                                  url
# 0                 https://realpython.com/python-csv/
# 1  https://realpython.com/iterate-through-diction...
# 2           https://realpython.com/python-f-strings/
# 3                   https://basketball.com/coachfui/

# %%
tutorials.delete_many({})
tutorials.insert_many([tutorial1, tutorial2, tutorial3, tutorial4])
df_tutorials = show_collect(tutorials, {})
df_tutorials
# rollback
# Out:
#                                                title     author  \
# 0            Reading and Writing CSV Files in Python        Jon
# 1      How to Iterate Through a Dictionary in Python   Leodanis
# 2  Python 3's f-Strings: An Improved String Forma...     Joanna
# 3                               Basket Ball Training  Coach Fui
#
#                          contributors  \
# 0  [Aldren, Geir Arne, Joanna, Jason]
# 1               [Aldren, Jim, Joanna]
# 2   [Adriana, David, Dan, Jim, Pavel]
# 3            [Thomson Yeung, Adam Ma]
#
#                                                  url
# 0                 https://realpython.com/python-csv/
# 1  https://realpython.com/iterate-through-diction...
# 2           https://realpython.com/python-f-strings/
# 3                   https://basketball.com/coachfui/

# %%
D_name={}
for index, row in df_tutorials.iterrows():
    D_name[index] = row['title']
    print(f"{index+1}. Contributors of title: {D_name[index]}")
    for i in row['contributors']:
        print(" - ", i)
    #print(index, row['Name'])
D_name
# Out:
# 1. Contributors of title: Reading and Writing CSV Files in Python
#  -  Aldren
#  -  Geir Arne
#  -  Joanna
#  -  Jason
# 2. Contributors of title: How to Iterate Through a Dictionary in Python
#  -  Aldren
#  -  Jim
#  -  Joanna
# 3. Contributors of title: Python 3's f-Strings: An Improved String Formatting Syntax
#  -  Adriana
#  -  David
#  -  Dan
#  -  Jim
#  -  Pavel
# 4. Contributors of title: Basket Ball Training
#  -  Thomson Yeung
#  -  Adam Ma
# {0: 'Reading and Writing CSV Files in Python',
#  1: 'How to Iterate Through a Dictionary in Python',
#  2: "Python 3's f-Strings: An Improved String Formatting Syntax",
#  3: 'Basket Ball Training'}

# %%
client.close()

# %% [markdown]
# ## Lesson 3

# %%
tutorial5 = {
     "title": "これからはじめるReact実践入門",
     "author": "山田　祥寛",
     "contributors": [
         "白石麻衣",
         "西野カナ",
         "中森明菜"
     ],
    "location" : {
                "room" : "5/F",
                "district" : "Shibuya, Tokyo"
                },
     "url": "https://www.sbcr.jp/product/4815617837/"
}

tutorial6 = {
    "title": "新・明解Python入門 第2版",
    "author": "柴田 望洋",
    "contributors": [
        "久保詩織",
        "トムソン"
    ],
    "location" : {
                "room" : "10/F",
                "district" : "Shinjuku, Tokyo"
                },
    "url": "https://www.sbcr.jp/product/4815619480/"
}

# %%
url = 'mongodb://localhost:27017'
client = MongoClient(url)

db = client['mydb']
tutorials = db['tutorials']

tutorials.insert_many([tutorial5, tutorial6])

# %%
df_tutorials = show_collect(tutorials, {})
df_tutorials
# select * from tutorials
# Out:
#                                                title     author  \
# 0            Reading and Writing CSV Files in Python        Jon
# 1      How to Iterate Through a Dictionary in Python   Leodanis
# 2  Python 3's f-Strings: An Improved String Forma...     Joanna
# 3                               Basket Ball Training  Coach Fui
# 4                                  これからはじめるReact実践入門      山田　祥寛
# 5                                   新・明解Python入門 第2版      柴田 望洋
#
#                          contributors  \
# 0  [Aldren, Geir Arne, Joanna, Jason]
# 1               [Aldren, Jim, Joanna]
# 2   [Adriana, David, Dan, Jim, Pavel]
# 3            [Thomson Yeung, Adam Ma]
# 4                  [白石麻衣, 西野カナ, 中森明菜]
# 5                        [久保詩織, トムソン]
#
#                                                  url  \
# 0                 https://realpython.com/python-csv/
# 1  https://realpython.com/iterate-through-diction...
# 2           https://realpython.com/python-f-strings/
# 3                   https://basketball.com/coachfui/
# 4            https://www.sbcr.jp/product/4815617837/
# 5            https://www.sbcr.jp/product/4815619480/
#
#                                           location
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4    {'room': '5/F', 'district': 'Shibuya, Tokyo'}
# 5  {'room': '10/F', 'district': 'Shinjuku, Tokyo'}

# %%
myquery = {'author': '柴田 望洋'}
df_tutorials = show_collect(tutorials, myquery)
df_tutorials
# select * from tutorials where author = '柴田 望洋'
# Out:
#               title author  contributors  \
# 0  新・明解Python入門 第2版  柴田 望洋  [久保詩織, トムソン]
#
#                                           location  \
# 0  {'room': '10/F', 'district': 'Shinjuku, Tokyo'}
#
#                                        url
# 0  https://www.sbcr.jp/product/4815619480/

# %%
myquery = {'location.district': 'Shibuya, Tokyo'}
df_tutorials = show_collect(tutorials, myquery)
df_tutorials
# select * from tutorials where author = '柴田 望洋'
# Out:
#                title author        contributors  \
# 0  これからはじめるReact実践入門  山田　祥寛  [白石麻衣, 西野カナ, 中森明菜]
#
#                                         location  \
# 0  {'room': '5/F', 'district': 'Shibuya, Tokyo'}
#
#                                        url
# 0  https://www.sbcr.jp/product/4815617837/

# %%
df_tutorials = show_collect(tutorials, {})
D_name={}
for index, row in df_tutorials.iterrows():
    D_name[index] = row['title']
    print(f"{index+1}. Contributors of title: {D_name[index]}")
    for i in row['contributors']:
        print(" - ", i)
    location = row['location']
    #print(location)
    if not pd.isna(location):
        print(f" - Location : {location['room']} {location['district']}")
    #print(index, row['Name'])
D_name
# Out:
# 1. Contributors of title: Reading and Writing CSV Files in Python
#  -  Aldren
#  -  Geir Arne
#  -  Joanna
#  -  Jason
# 2. Contributors of title: How to Iterate Through a Dictionary in Python
#  -  Aldren
#  -  Jim
#  -  Joanna
# 3. Contributors of title: Python 3's f-Strings: An Improved String Formatting Syntax
#  -  Adriana
#  -  David
#  -  Dan
#  -  Jim
#  -  Pavel
# 4. Contributors of title: Basket Ball Training
#  -  Thomson Yeung
#  -  Adam Ma
# 5. Contributors of title: これからはじめるReact実践入門
#  -  白石麻衣
#  -  西野カナ
#  -  中森明菜
#  - Location : 5/F Shibuya, Tokyo
# 6. Contributors of title: 新・明解Python入門 第2版
#  -  久保詩織
#  -  トムソン
#  - Location : 10/F Shinjuku, Tokyo
# {0: 'Reading and Writing CSV Files in Python',
#  1: 'How to Iterate Through a Dictionary in Python',
#  2: "Python 3's f-Strings: An Improved String Formatting Syntax",
#  3: 'Basket Ball Training',
#  4: 'これからはじめるReact実践入門',
#  5: '新・明解Python入門 第2版'}

# %%
client.close()
